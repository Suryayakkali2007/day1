# %%
import pandas as pd
url="https://www.kaggle.com/datasets/uciml/iris"
df=pd.read_csv("Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
numerical_cols=df.select_dtypes(include=[int,float]).columns.tolist()
numerical_cols=numerical_cols[1:]
df[numerical_cols]=scaler.fit_transform(df[numerical_cols])
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1       0.222222      0.625000       0.067797      0.041667  Iris-setosa
# 1   2       0.166667      0.416667       0.067797      0.041667  Iris-setosa
# 2   3       0.111111      0.500000       0.050847      0.041667  Iris-setosa
# 3   4       0.083333      0.458333       0.084746      0.041667  Iris-setosa
# 4   5       0.194444      0.666667       0.067797      0.041667  Iris-setosa

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
x_test,x_train,y_test,y_train=train_test_split(df[numerical_cols],df["Species"],test_size=0.2,random_state=42)
k_values = range(1, 21)

accuracies = []

print("Evaluating KNN with different k values:")
for k in k_values:
    knn_model = KNeighborsClassifier(n_neighbors=k)
    knn_model.fit(x_train, y_train)
    y_pred_k = knn_model.predict(x_test)
    accuracy_k = accuracy_score(y_test, y_pred_k)
    accuracies.append(accuracy_k)
    print(f"k = {k}: Accuracy = {accuracy_k:.4f}")

best_k_index = accuracies.index(max(accuracies))
best_k = k_values[best_k_index]
best_accuracy = accuracies[best_k_index]

print(f"\nBest k value found: {best_k} with an accuracy of {best_accuracy:.4f}")
# Out:
# Evaluating KNN with different k values:
# k = 1: Accuracy = 0.9500
# k = 2: Accuracy = 0.9250
# k = 3: Accuracy = 0.9417
# k = 4: Accuracy = 0.9500
# k = 5: Accuracy = 0.9583
# k = 6: Accuracy = 0.9583
# k = 7: Accuracy = 0.9500
# k = 8: Accuracy = 0.9333
# k = 9: Accuracy = 0.9417
# k = 10: Accuracy = 0.9250
# k = 11: Accuracy = 0.9250
# k = 12: Accuracy = 0.9250
# k = 13: Accuracy = 0.9167
# k = 14: Accuracy = 0.8667
# k = 15: Accuracy = 0.8583
# k = 16: Accuracy = 0.8750
# k = 17: Accuracy = 0.8917
# k = 18: Accuracy = 0.8583
# k = 19: Accuracy = 0.8500
# k = 20: Accuracy = 0.8333
#
# Best k value found: 5 with an accuracy of 0.9583

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(k_values, accuracies, marker='o', linestyle='-')
plt.title('KNN Accuracy vs. Number of Neighbors (k)')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Accuracy')
plt.xticks(k_values)
plt.grid(True)
plt.show()

# %% [markdown]
# # Summary
#
# We have performed the following tasks:
#
# 1.  **Loaded the Iris dataset** from a URL into a Pandas DataFrame.
# 2.  **Normalized the numerical features** of the dataset using `MinMaxScaler`.
# 3.  **Split the data** into training and testing sets.
# 4.  **Trained and evaluated a K-Nearest Neighbors (KNN) classifier**.
# 5.  **Iterated through various 'k' values** to find the optimal number of neighbors for the KNN model.
# 6.  **Visualized the accuracy** of the KNN model for different 'k' values to determine the best performing 'k'.
